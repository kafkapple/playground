# %%
import model.test_model_reuse as apple
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
loaded_model = apple.load_trained_model('./model/sm_net.json', './model/sm_net.h5')

#save_trained_model_and_weight()
# Out:
# ddd
# Model & weight are loaded separately.

# %%
apple.save_trained_model_and_weight(loaded_model, 'new_test23', './nnn/f2/')
# Out:
# Model & Weight are saved separatedly. (model: .json) (weight: .h5)

# %%
loaded_model.sa

# %%
new_model = apple.load_trained_model('test.h5')
# Out:
# ddd
# Model & weight are loaded altogether.
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py:269: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
# Out:
# [array([[[[-0.01206489, -0.0434384 ,  0.00879475, ...,  0.0256807 ,
#             0.05901674, -0.00634309]],
#
#          [[-0.05560192,  0.02697629,  0.03954988, ...,  0.03778194,
#             0.06000013,  0.03297539]],
#
#          [[ 0.04811464,  0.02919848, -0.0428944 , ...,  0.0313134 ,
#            -0.03803097,  0.05162658]],
#
#          [[-0.03391181,  0.05038543,  0.03978243, ...,  0.0447675 ,
#             0.03058628, -0.02647478]],
#
#          [[ 0.05144604,  0.02338376,  0.00476928, ...,  0.04575106,
#            -0.05241814, -0.0020086 ]]],
#
#
#         [[[ 0.00664641, -0.04473128, -0.0164612 , ..., -0.06011266,
#             0.01947632,  0.05084615]],
#
#          [[-0.03225871, -0.04067421, -0.05308353, ..., -0.02725083,
#             0.01472544,  0.01879615]],
#
#          [[ 0.05506831, -0.01524811, -0.04999806, ...,  0.02694881,
#            -0.00432911, -0.03104869]],
#
#          [[-0.02328054, -0.02439163,  0.03183618, ..., -0.04520576,
# ...
