# %%
temp=[0]*13
count=0
a=['a']*5
b=['b']*5
c=['c']*5

bc=['bc','cb']
a_c = 5
b_c = 5
c_c = 5
#total = a+b+c


tt = list('a a a a a')

# 1,3,5,7 에 bc 들어감
import itertools
from itertools import permutations
accum = []
a = 'a a a a a'
n=4
for i in range(16):
    
    bin_num = bin(i)[2:]
    temp_bin = ['0']*(n-len(bin_num))+list(bin_num)
    temp_bin = [bc[int(i)] for i in temp_bin]
    accum.append(temp_bin)
    print(temp_bin)
    
#tt=accum[0]
#tt.insert(0,'test')
#0 2 4 6 8 
for i in accum:
    for j in range(5):
        i.insert(j*2, 'a')
        
accum
#set([''.join(j) for j in accum])
# 13개. 2개 필요.
#10 군데 중 2군데. 

#np.arange(10)
#test = accum[0]
#1~8 중 하나


#accum
n_r = np.arange(10)

test = ['a', 'bc', 'a', 'bc', 'a', 'bc', 'a', 'bc', 'a']
#test.insert(14,'new')
test

cur_sec = []
cur_3=[]

for acc in accum:
    test = acc
    
    # 1. 겹치지 않게 하나씩. 
    bc=['b','c']

    for k in range(2):
        for i in n_r:
            for j in np.arange(i+1,10):
                temp = test.copy() 
                temp.insert(j,bc[k])
                temp.insert(i,bc[(k+1)%2])
                #print(temp)
                cur_sec.append(''.join(temp))
    # 쌍으로 두개 묶어서
    bcbc = ['bc','cb']
    
    for k in range(2):
        for i in np.arange(8):
            temp = test.copy() 
            temp.insert(i,bcbc[k])
            #print(temp)
            cur_3.append(''.join(temp))
    
len(set(cur_3)) # 45 가지 *2 (bc, cb) + 21 
len(set(cur_sec)) # 45 가지 *2 (bc, cb) + 21 
#total = cur_3.append(cur_sec)
total = cur_3+cur_sec
#total = [list(i) for i in total]
len(set(total))
set_total = list(set(total))
chk = ['a','b','c']
#new2 = [i for i in set_total if i.count(chk[2]) != 5]
new2 = [i for i in set_total if 'acba'in i]

len(new2)
len(set_total)
# 1072
